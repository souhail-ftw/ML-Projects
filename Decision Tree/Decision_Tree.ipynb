# %%
import pandas as pd

# %%
df = pd.read_csv('Titanic Passengers.csv')

# %%
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket     fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.338       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.550  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.550  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.550  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.550  C22 C26        S  NaN    NaN
#
#                           homedest
# ...

# %%
df.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age          263
# sibsp          0
# parch          0
# ticket         0
# fare           1
# cabin       1014
# embarked       2
# boat         823
# body        1188
# homedest     564
# dtype: int64

# %%
def preprocess_data(new_data):
    df['age'].fillna(new_data['age'].mean(),inplace=True)
    df.replace({'sex':{'male': 1,'female':0}},inplace=True)
    df['cabin']=new_data.cabin.fillna('G6')
    df.replace({'survived':{'Yes': 1,'No':0}},inplace=True)
    return new_data
data=preprocess_data(df)

# %%
df.head()
# Out:
#    pclass  survived                                             name  sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton    0
# 1       1         1                   Allison, Master. Hudson Trevor    1
# 2       1         0                     Allison, Miss. Helen Loraine    0
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    1
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    0
#
#        age  sibsp  parch  ticket     fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.338       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.550  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.550  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.550  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.550  C22 C26        S  NaN    NaN
#
#                           homedest
# 0                     St Louis, MO
# ...

# %%
df.isna().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           1
# cabin          0
# embarked       2
# boat         823
# body        1188
# homedest     564
# dtype: int64

# %%
df.isnull().sum()
# Out:
# pclass         0
# survived       0
# name           0
# sex            0
# age            0
# sibsp          0
# parch          0
# ticket         0
# fare           1
# cabin          0
# embarked       2
# boat         823
# body        1188
# homedest     564
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
#features extraction
x= (["survived", "name", "cabin", "ticket", "embarked"])
x = x.apply(pd.to_numeric, errors='coerce')
y= data["survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)
#applying tree algorithm
tree = tree.DecisionTreeClassifier()
tree.fit(x_train, y_train)
y_pred=tree.predict(x_test)
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-6d511a6d65a9> in <cell line: 7>()
#       5 #features extraction
#       6 x= (["survived", "name", "cabin", "ticket", "embarked"])
# ----> 7 x = x.apply(pd.to_numeric, errors='coerce')
#       8 y= data["survived"]
#       9
#
# AttributeError: 'list' object has no attribute 'apply'

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Plot the decision tree
plt.figure(figsize=(20,10))  # You can adjust the size for better visualization
plot_tree(tree, filled=True, feature_names=x.columns, class_names=['Not Survived', 'Survived'], rounded=True)
plt.show()
